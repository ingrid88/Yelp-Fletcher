# %% [markdown]
# ## Import clusters

# %%
import pickle
cluster_list = pickle.load(open("affinity_prop.pkl", "rb"))

# %%
result = pickle.load(open("spacy_similarity_result_2.p", "rb"))

# %%
import numpy as np

# %%
data = [np.array(result[0]).astype(int), np.array(result[1]).astype(int), np.array(result[2])]
datum = np.array(data)
# datum = datum.T

# %%
df = pd.DataFrame(datum).T

# %%
df[df[0] == 316][df[1].isin(clusters)]
# Out:
# /Users/ingrid/anaconda/lib/python3.5/site-packages/pandas/core/frame.py:1997: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)
#           0    1         2
# 948000  316    0  0.969197
# 948001  316    1  0.796268
# 948002  316    2  0.973608
# 948003  316    3  0.939777
# 948004  316    4  0.963337
# 948005  316    5  0.967662
# 948006  316    6  0.969820
# 948007  316    7  0.949826
# 948008  316    8  0.969142
# 948009  316    9  0.966641
# 948010  316   10  0.949099
# 948011  316   11  0.965598
# 948012  316   12  0.965738
# 948013  316   13  0.972017
# 948014  316   14  0.942055
# 948015  316   15  0.936357
# 948016  316   16  0.973864
# 948017  316   17  0.974374
# 948018  316   18  0.961218
# 948019  316   19  0.956251
# 948020  316   20  0.967603
# 948021  316   21  0.965331
# 948022  316   22  0.955276
# 948023  316   23  0.965836
# 948024  316   24  0.943580
# 948025  316   25  0.973229
# 948026  316   26  0.932817
# 948027  316   27  0.943705
# 948028  316   28  0.891132
# 948029  316   29  0.974082
# ...     ...  ...       ...
# 948345  316  345  0.962322
# 948346  316  346  0.969105
# 948347  316  347  0.935010
# 948348  316  348  0.950026
# 948349  316  349  0.836262
# 948350  316  350  0.786300
# 948351  316  351  0.956125
# 948352  316  352  0.963182
# 948353  316  353  0.974980
# 948354  316  354  0.955429
# 948355  316  355  0.962465
# 948356  316  356  0.969124
# 948357  316  357  0.958318
# 948358  316  358  0.974948
# 948359  316  359  0.966875
# 948360  316  360  0.959053
# 948361  316  361  0.954523
# 948362  316  362  0.950626
# 948363  316  363  0.940245
# 948364  316  364  0.955172
# 948365  316  365  0.973028
# 948366  316  366  0.935813
# 948367  316  367  0.913314
# 948368  316  368  0.954654
# 948369  316  369  0.972873
# 948370  316  370  0.961215
# 948371  316  371  0.968619
# 948372  316  372  0.965401
# 948373  316  373  0.972790
# 948374  316  374  0.951675
#
# [375 rows x 3 columns]

# %%
import pandas as pd

# %%
clusters = cluster_list[0].tolist()
